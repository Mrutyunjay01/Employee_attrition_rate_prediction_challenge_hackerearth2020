# %%
import pandas as pd
import pandas_profiling

# %%
import pandas as pd

train_file = 'Dataset/Train.csv'
test_file = 'Dataset/Test.csv'

train_df = pd.read_csv(train_file)
test_df = pd.read_csv(test_file)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7000 entries, 0 to 6999
# Data columns (total 24 columns):
# Employee_ID                  7000 non-null object
# Gender                       7000 non-null object
# Age                          6588 non-null float64
# Education_Level              7000 non-null int64
# Relationship_Status          7000 non-null object
# Hometown                     7000 non-null object
# Unit                         7000 non-null object
# Decision_skill_possess       7000 non-null object
# Time_of_service              6856 non-null float64
# Time_since_promotion         7000 non-null int64
# growth_rate                  7000 non-null int64
# Travel_Rate                  7000 non-null int64
# Post_Level                   7000 non-null int64
# Pay_Scale                    6991 non-null float64
# Compensation_and_Benefits    7000 non-null object
# Work_Life_balance            6989 non-null float64
# VAR1                         7000 non-null int64
# ...

# %%
train_df.describe()
# Out:
#                Age  Education_Level  Time_of_service  Time_since_promotion  \
# count  6588.000000      7000.000000      6856.000000           7000.000000
# mean     39.622799         3.187857        13.385064              2.367143
# std      13.606920         1.065102        10.364188              1.149395
# min      19.000000         1.000000         0.000000              0.000000
# 25%      27.000000         3.000000         5.000000              1.000000
# 50%      37.000000         3.000000        10.000000              2.000000
# 75%      52.000000         4.000000        21.000000              3.000000
# max      65.000000         5.000000        43.000000              4.000000
#
#        growth_rate  Travel_Rate   Post_Level    Pay_Scale  Work_Life_balance  \
# count  7000.000000  7000.000000  7000.000000  6991.000000        6989.000000
# mean     47.064286     0.817857     2.798000     6.006294           2.387895
# ...

# %%
train_df = train_df.fillna(0)
train_df
# Out:
#      Employee_ID Gender   Age  Education_Level Relationship_Status  \
# 0      EID_23371      F  42.0                4             Married
# 1      EID_18000      M  24.0                3              Single
# 2       EID_3891      F  58.0                3             Married
# 3      EID_17492      F  26.0                3              Single
# 4      EID_22534      F  31.0                1             Married
# ...          ...    ...   ...              ...                 ...
# 6995   EID_16328      F  23.0                5             Married
# 6996    EID_8387      F  44.0                1             Married
# 6997    EID_8077      F  49.0                3              Single
# 6998   EID_19597      F  47.0                3             Married
# 6999    EID_1640      F  58.0                3             Married
#
#          Hometown                       Unit Decision_skill_possess  \
# 0        Franklin                         IT             Conceptual
# ...

# %%
train_df.corr()['Attrition_rate'].sort_values(ascending=False)
# Out:
# Attrition_rate          1.000000
# Work_Life_balance       0.021115
# Post_Level              0.016402
# growth_rate             0.014247
# Time_since_promotion    0.013880
# VAR3                    0.001245
# VAR4                    0.001051
# VAR6                   -0.003130
# VAR5                   -0.004770
# VAR1                   -0.008073
# Education_Level        -0.008143
# Age                    -0.008505
# Travel_Rate            -0.012608
# VAR7                   -0.015299
# Pay_Scale              -0.015643
# Time_of_service        -0.019863
# VAR2                   -0.022906
# Name: Attrition_rate, dtype: float64

# %%
train_df = train_df.drop(columns=['VAR3', 'VAR6', 'VAR5', 'VAR1', 'Education_Level', 'VAR4', 'Age'])

# %%
train_df.isna().sum()
# Out:
# Employee_ID                  0
# Gender                       0
# Relationship_Status          0
# Hometown                     0
# Unit                         0
# Decision_skill_possess       0
# Time_of_service              0
# Time_since_promotion         0
# growth_rate                  0
# Travel_Rate                  0
# Post_Level                   0
# Pay_Scale                    0
# Compensation_and_Benefits    0
# Work_Life_balance            0
# VAR2                         0
# VAR7                         0
# Attrition_rate               0
# dtype: int64

# %%
categorical_values = train_df.select_dtypes('object')
categorical_values = categorical_values.drop(['Employee_ID'], axis=1)
categorical_values
# Out:
#      Gender Relationship_Status     Hometown                       Unit  \
# 0         F             Married     Franklin                         IT
# 1         M              Single  Springfield                  Logistics
# 2         F             Married      Clinton                    Quality
# 3         F              Single      Lebanon  Human Resource Management
# 4         F             Married  Springfield                  Logistics
# ...     ...                 ...          ...                        ...
# 6995      F             Married     Franklin                 Operarions
# 6996      F             Married      Lebanon                        R&D
# 6997      F              Single  Springfield                         IT
# 6998      F             Married   Washington                      Sales
# 6999      F             Married     Franklin                         IT
#
#      Decision_skill_possess Compensation_and_Benefits
# ...

# %%
dummies_categorical = pd.get_dummies(categorical_values)

# %%
dummies_categorical
# Out:
#       Gender_F  Gender_M  Relationship_Status_Married  \
# 0            1         0                            1
# 1            0         1                            0
# 2            1         0                            1
# 3            1         0                            0
# 4            1         0                            1
# ...        ...       ...                          ...
# 6995         1         0                            1
# 6996         1         0                            1
# 6997         1         0                            0
# 6998         1         0                            1
# 6999         1         0                            1
#
#       Relationship_Status_Single  Hometown_Clinton  Hometown_Franklin  \
# 0                              0                 0                  1
# 1                              1                 0                  0
# 2                              0                 1                  0
# ...

# %%
train_df
# Out:
#      Employee_ID Gender Relationship_Status     Hometown  \
# 0      EID_23371      F             Married     Franklin
# 1      EID_18000      M              Single  Springfield
# 2       EID_3891      F             Married      Clinton
# 3      EID_17492      F              Single      Lebanon
# 4      EID_22534      F             Married  Springfield
# ...          ...    ...                 ...          ...
# 6995   EID_16328      F             Married     Franklin
# 6996    EID_8387      F             Married      Lebanon
# 6997    EID_8077      F              Single  Springfield
# 6998   EID_19597      F             Married   Washington
# 6999    EID_1640      F             Married     Franklin
#
#                            Unit Decision_skill_possess  Time_of_service  \
# 0                            IT             Conceptual              4.0
# 1                     Logistics             Analytical              5.0
# ...

# %%
train_features_final = pd.concat([train_df, dummies_categorical], axis=1)

# %%
train_features_final
# Out:
#      Employee_ID Gender Relationship_Status     Hometown  \
# 0      EID_23371      F             Married     Franklin
# 1      EID_18000      M              Single  Springfield
# 2       EID_3891      F             Married      Clinton
# 3      EID_17492      F              Single      Lebanon
# 4      EID_22534      F             Married  Springfield
# ...          ...    ...                 ...          ...
# 6995   EID_16328      F             Married     Franklin
# 6996    EID_8387      F             Married      Lebanon
# 6997    EID_8077      F              Single  Springfield
# 6998   EID_19597      F             Married   Washington
# 6999    EID_1640      F             Married     Franklin
#
#                            Unit Decision_skill_possess  Time_of_service  \
# 0                            IT             Conceptual              4.0
# 1                     Logistics             Analytical              5.0
# ...

# %%
train_features_final = train_features_final.drop(columns=categorical_values.columns.to_list())
train_features_final
# Out:
#      Employee_ID  Time_of_service  Time_since_promotion  growth_rate  \
# 0      EID_23371              4.0                     4           33
# 1      EID_18000              5.0                     4           36
# 2       EID_3891             27.0                     3           51
# 3      EID_17492              4.0                     3           56
# 4      EID_22534              5.0                     4           62
# ...          ...              ...                   ...          ...
# 6995   EID_16328              4.0                     1           20
# 6996    EID_8387             16.0                     2           59
# 6997    EID_8077             10.0                     1           59
# 6998   EID_19597             24.0                     1           21
# 6999    EID_1640             22.0                     2           74
#
#       Travel_Rate  Post_Level  Pay_Scale  Work_Life_balance    VAR2  VAR7  \
# ...

# %%
train_features_final = train_features_final.drop(['Employee_ID'], axis=1)
train_features_final
# Out:
#       Time_of_service  Time_since_promotion  growth_rate  Travel_Rate  \
# 0                 4.0                     4           33            1
# 1                 5.0                     4           36            0
# 2                27.0                     3           51            0
# 3                 4.0                     3           56            1
# 4                 5.0                     4           62            1
# ...               ...                   ...          ...          ...
# 6995              4.0                     1           20            1
# 6996             16.0                     2           59            0
# 6997             10.0                     1           59            1
# 6998             24.0                     1           21            1
# 6999             22.0                     2           74            0
#
#       Post_Level  Pay_Scale  Work_Life_balance    VAR2  VAR7  Attrition_rate  \
# ...

# %%
train_features_final.corr()['Attrition_rate'].sort_values(ascending=False)
# Out:
# Attrition_rate                       1.000000
# Gender_M                             0.028544
# Compensation_and_Benefits_type0      0.026905
# Work_Life_balance                    0.021115
# Decision_skill_possess_Conceptual    0.016568
# Post_Level                           0.016402
# Unit_Purchasing                      0.015279
# Unit_Operarions                      0.015147
# Hometown_Springfield                 0.014555
# growth_rate                          0.014247
# Time_since_promotion                 0.013880
# Unit_R&D                             0.013868
# Decision_skill_possess_Directive     0.013680
# Compensation_and_Benefits_type1      0.010370
# Relationship_Status_Single           0.009107
# Unit_Sales                           0.007789
# Compensation_and_Benefits_type2      0.005273
# Unit_Marketing                       0.002422
# Unit_Production                      0.001297
# Unit_Security                        0.001183
# ...

# %%
test_df
# Out:
#      Employee_ID Gender   Age  Education_Level Relationship_Status  \
# 0      EID_22713      F  32.0                5              Single
# 1       EID_9658      M  65.0                2              Single
# 2      EID_22203      M  52.0                3             Married
# 3       EID_7652      M  50.0                5              Single
# 4       EID_6516      F  44.0                3             Married
# ...          ...    ...   ...              ...                 ...
# 2995   EID_22547      F  32.0                3              Single
# 2996   EID_10066      F   NaN                2              Single
# 2997    EID_7126      F  60.0                4              Single
# 2998    EID_4929      F  51.0                1             Married
# 2999   EID_24750      F  45.0                1              Single
#
#          Hometown       Unit Decision_skill_possess  Time_of_service  \
# 0     Springfield        R&D             Conceptual              7.0
# ...

# %%
import xgboost as xgb
from bayes_opt import BayesianOptimization

dtrain = xgb.DMatrix(train_features_final.drop(['Attrition_rate'], axis=1), train_features_final['Attrition_rate'])

import warnings
warnings.simplefilter("ignore")

#Bayesian Optimization function for xgboost
#specify the parameters you want to tune as keyword arguments
def bo_tune_xgb(max_depth, gamma,learning_rate):
    
    params = {'max_depth': int(max_depth),
              'gamma': gamma,
              'learning_rate':learning_rate,
              'subsample': 0.8,
              'eta': 0.1,
              'eval_metric': 'rmse'}
    #Cross validating with the specified parameters in 5 folds and 70 iterations
    cv_result = xgb.cv(params, dtrain, num_boost_round=70, nfold=5)
    #Return the negative RMSE
    return -1.0 * cv_result['test-rmse-mean'].iloc[-1]

#Invoking the Bayesian Optimizer with the specified parameters to tune
xgb_bo = BayesianOptimization(bo_tune_xgb, {'max_depth': (3, 10),
                                             'gamma': (0, 1),
                                             'learning_rate':(0,1),
                                            })

#performing Bayesian optimization for 5 iterations with 8 steps of random exploration with an #acquisition function of expected improvement
xgb_bo.maximize(n_iter=5, init_points=8, acq='ei')
# Out:
# |   iter    |  target   |   gamma   | learni... | max_depth |
# -------------------------------------------------------------
# |  1        | -0.2094   |  0.1435   |  0.4934   |  9.029    |
# |  2        | -0.1959   |  0.2268   |  0.2679   |  8.516    |
# |  3        | -0.1874   |  0.9922   |  0.7465   |  9.384    |
# |  4        | -0.1857   |  0.8225   |  0.9704   |  3.802    |
# |  5        | -0.19     |  0.5478   |  0.6191   |  5.023    |
# |  6        | -0.2034   |  0.2126   |  0.4688   |  8.227    |
# |  7        | -0.1873   |  0.1179   |  0.04569  |  5.651    |
# |  8        | -0.1868   |  0.8983   |  0.0385   |  9.786    |
# |  9        | -0.3619   |  1.0      |  0.0      |  3.0      |
# |  10       | -0.209    |  0.0      |  1.0      |  3.997    |
# |  11       | -0.1871   |  1.0      |  1.0      |  5.09     |
# |  12       | -0.3619   |  1.0      |  0.0      |  7.74     |
# |  13       | -0.2502   |  0.0      |  1.0      |  5.626    |
# ...

# %%
params = xgb_bo.max['params']
params['max_depth'] = int(params['max_depth'])

# %%
xgbreg = xgb.XGBRegressor(**(params)).fit(train_features_final.drop(['Attrition_rate'], axis=1), train_features_final['Attrition_rate'])

# %%
xgbreg.predict(train_features_final.drop(['Attrition_rate'], axis=1))
# Out:
# array([0.18937618, 0.18937618, 0.18937618, ..., 0.18937618, 0.18937618,
#        0.18937618], dtype=float32)

# %%
train_df.Attrition_rate.mean()
# Out:
# 0.1893761285714282

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

print(1 - np.sqrt(mean_squared_error(train_features_final['Attrition_rate'], xgbreg.predict(train_features_final.drop(['Attrition_rate'], axis=1)))))
# Out:
# 0.8142599907777773

# %%
test_features = test_df.drop(columns=['VAR3', 'VAR6', 'VAR5', 'VAR1', 'Education_Level', 'VAR4', 'Age', 'Employee_ID'])
test_features
# Out:
#      Gender Relationship_Status     Hometown       Unit  \
# 0         F              Single  Springfield        R&D
# 1         M              Single      Lebanon         IT
# 2         M             Married  Springfield      Sales
# 3         M              Single   Washington  Marketing
# 4         F             Married     Franklin        R&D
# ...     ...                 ...          ...        ...
# 2995      F              Single     Franklin      Sales
# 2996      F              Single     Franklin  Marketing
# 2997      F              Single      Lebanon  Logistics
# 2998      F             Married  Springfield         IT
# 2999      F              Single     Franklin      Sales
#
#      Decision_skill_possess  Time_of_service  Time_since_promotion  \
# 0                Conceptual              7.0                     4
# 1                 Directive             41.0                     2
# 2                 Directive             21.0                     3
# ...

# %%
categorical_test = test_features.select_dtypes('object')
categorical_test_dummies = pd.get_dummies(categorical_test)
test_pre_final = pd.concat([test_features, categorical_test_dummies], axis=1)
test_pre_final
# Out:
#      Gender Relationship_Status     Hometown       Unit  \
# 0         F              Single  Springfield        R&D
# 1         M              Single      Lebanon         IT
# 2         M             Married  Springfield      Sales
# 3         M              Single   Washington  Marketing
# 4         F             Married     Franklin        R&D
# ...     ...                 ...          ...        ...
# 2995      F              Single     Franklin      Sales
# 2996      F              Single     Franklin  Marketing
# 2997      F              Single      Lebanon  Logistics
# 2998      F             Married  Springfield         IT
# 2999      F              Single     Franklin      Sales
#
#      Decision_skill_possess  Time_of_service  Time_since_promotion  \
# 0                Conceptual              7.0                     4
# 1                 Directive             41.0                     2
# 2                 Directive             21.0                     3
# ...

# %%
test_final = test_pre_final.drop(columns=categorical_test.columns.to_list())
test_final
# Out:
#       Time_of_service  Time_since_promotion  growth_rate  Travel_Rate  \
# 0                 7.0                     4           30            1
# 1                41.0                     2           72            1
# 2                21.0                     3           25            0
# 3                11.0                     4           28            1
# 4                12.0                     4           47            1
# ...               ...                   ...          ...          ...
# 2995              3.0                     3           38            1
# 2996             10.0                     2           57            1
# 2997             35.0                     1           69            0
# 2998             23.0                     1           30            0
# 2999             12.0                     4           70            1
#
#       Post_Level  Pay_Scale  Work_Life_balance    VAR2  VAR7  Gender_F  ...  \
# ...

# %%
train_features_final
# Out:
#       Time_of_service  Time_since_promotion  growth_rate  Travel_Rate  \
# 0                 4.0                     4           33            1
# 1                 5.0                     4           36            0
# 2                27.0                     3           51            0
# 3                 4.0                     3           56            1
# 4                 5.0                     4           62            1
# ...               ...                   ...          ...          ...
# 6995              4.0                     1           20            1
# 6996             16.0                     2           59            0
# 6997             10.0                     1           59            1
# 6998             24.0                     1           21            1
# 6999             22.0                     2           74            0
#
#       Post_Level  Pay_Scale  Work_Life_balance    VAR2  VAR7  Attrition_rate  \
# ...

# %%
pred_test = xgbreg.predict(test_final)
pred_test
# Out:
# array([0.18937618, 0.18937618, 0.18937618, ..., 0.18937618, 0.18937618,
#        0.18937618], dtype=float32)

# %%
test_df
# Out:
#      Employee_ID Gender   Age  Education_Level Relationship_Status  \
# 0      EID_22713      F  32.0                5              Single
# 1       EID_9658      M  65.0                2              Single
# 2      EID_22203      M  52.0                3             Married
# 3       EID_7652      M  50.0                5              Single
# 4       EID_6516      F  44.0                3             Married
# ...          ...    ...   ...              ...                 ...
# 2995   EID_22547      F  32.0                3              Single
# 2996   EID_10066      F   NaN                2              Single
# 2997    EID_7126      F  60.0                4              Single
# 2998    EID_4929      F  51.0                1             Married
# 2999   EID_24750      F  45.0                1              Single
#
#          Hometown       Unit Decision_skill_possess  Time_of_service  \
# 0     Springfield        R&D             Conceptual              7.0
# ...

# %%
test_final = test_final.fillna(0)

# %%
submission = pd.DataFrame()
submission['Employee_ID'] = test_df['Employee_ID'].iloc[:]
submission['Attrition_rate'] = model.predict(StandardScaler().fit_transform(test_final))
submission
# Out:
#      Employee_ID  Attrition_rate
# 0      EID_22713        0.201567
# 1       EID_9658        0.343289
# 2      EID_22203        0.215056
# 3       EID_7652        0.185057
# 4       EID_6516        0.231423
# ...          ...             ...
# 2995   EID_22547        0.156351
# 2996   EID_10066        0.176520
# 2997    EID_7126        0.196348
# 2998    EID_4929        0.179281
# 2999   EID_24750        0.245468
#
# [3000 rows x 2 columns]

# %%
submission.Attrition_rate.mean()
# Out:
# 0.2064316727107158

# %%
submission.to_csv('Ans.csv', index=False)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

x_train, X_test, y_train, y_test = train_test_split(train_features_final.drop(['Attrition_rate'], axis=1), train_features_final['Attrition_rate'],
                                                   test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

x_train = StandardScaler().fit_transform(x_train)
X_test = StandardScaler().fit_transform(X_test)

# %%
model = RandomForestRegressor(n_jobs=-1)

estimators = np.arange(10, 200, 10)
scores = []
for n in estimators:
    model.set_params(n_estimators=n)
    model.fit(x_train, y_train)
    print(1 - np.sqrt(mean_squared_error(y_test, model.predict(X_test))), '\t', n)
# Out:
# 0.7991869800900709 	 10
# 0.8046131169231068 	 20
# 0.8043364803655655 	 30
# 0.8061407268334414 	 40
# 0.8074397704640783 	 50
# 0.8089246456311612 	 60
# 0.8072999529287469 	 70
# 0.8097103162453982 	 80
# 0.807993920932054 	 90
# 0.8089316817604485 	 100
# 0.8085661934303194 	 110
# 0.8075885709780694 	 120
# 0.8085647206741458 	 130
# 0.8087091170573397 	 140
# 0.8088031083568855 	 150
# 0.8083797057203862 	 160
# 0.8091814605048273 	 170
# 0.8089418255603282 	 180
# 0.8077613734638953 	 190

# %%
print(scores)

# %%
test_df
# Out:
#      Employee_ID Gender   Age  Education_Level Relationship_Status  \
# 0      EID_22713      F  32.0                5              Single
# 1       EID_9658      M  65.0                2              Single
# 2      EID_22203      M  52.0                3             Married
# 3       EID_7652      M  50.0                5              Single
# 4       EID_6516      F  44.0                3             Married
# ...          ...    ...   ...              ...                 ...
# 2995   EID_22547      F  32.0                3              Single
# 2996   EID_10066      F   NaN                2              Single
# 2997    EID_7126      F  60.0                4              Single
# 2998    EID_4929      F  51.0                1             Married
# 2999   EID_24750      F  45.0                1              Single
#
#          Hometown       Unit Decision_skill_possess  Time_of_service  \
# 0     Springfield        R&D             Conceptual              7.0
# ...

# %%
test_df.Gender.hist()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-62-ff783b6ecb99> in <module>
# ----> 1 test_df.Gender.hist()
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\plotting\_core.py in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, **kwds)
#      71     matplotlib.axes.Axes.hist : Plot a histogram using matplotlib.
#      72     """
# ---> 73     plot_backend = _get_plot_backend()
#      74     return plot_backend.hist_series(
#      75         self,
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\plotting\_core.py in _get_plot_backend(backend)
#    1599         # Because matplotlib is an optional dependency and first-party backend,
#    1600         # we need to attempt an import here to raise an ImportError if needed.
# -> 1601         import pandas.plotting._matplotlib as module
#    1602
# ...
