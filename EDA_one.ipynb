# %%
import pandas as pd

# %%
train_file_path = 'Dataset/Train.csv'
test_file_path = 'Dataset/Test.csv'
submission_file_path = 'Dataset/sample_submission.csv'

# %%
train_df = pd.read_csv(train_file_path)
test_df = pd.read_csv(test_file_path)
submission_df = pd.read_csv(submission_file_path)

# %%
train_df.head()
# Out:
#   Employee_ID Gender   Age  Education_Level Relationship_Status     Hometown  \
# 0   EID_23371      F  42.0                4             Married     Franklin
# 1   EID_18000      M  24.0                3              Single  Springfield
# 2    EID_3891      F  58.0                3             Married      Clinton
# 3   EID_17492      F  26.0                3              Single      Lebanon
# 4   EID_22534      F  31.0                1             Married  Springfield
#
#                         Unit Decision_skill_possess  Time_of_service  \
# 0                         IT             Conceptual              4.0
# 1                  Logistics             Analytical              5.0
# 2                    Quality             Conceptual             27.0
# 3  Human Resource Management             Behavioral              4.0
# 4                  Logistics             Conceptual              5.0
#
#    Time_since_promotion  ...  Compensation_and_Benefits  Work_Life_balance  \
# ...

# %%
test_df.head()
# Out:
#   Employee_ID Gender   Age  Education_Level Relationship_Status     Hometown  \
# 0   EID_22713      F  32.0                5              Single  Springfield
# 1    EID_9658      M  65.0                2              Single      Lebanon
# 2   EID_22203      M  52.0                3             Married  Springfield
# 3    EID_7652      M  50.0                5              Single   Washington
# 4    EID_6516      F  44.0                3             Married     Franklin
#
#         Unit Decision_skill_possess  Time_of_service  Time_since_promotion  \
# 0        R&D             Conceptual              7.0                     4
# 1         IT              Directive             41.0                     2
# 2      Sales              Directive             21.0                     3
# 3  Marketing             Analytical             11.0                     4
# 4        R&D             Conceptual             12.0                     4
#
# ...

# %%
submission_df.head()
# Out:
#   Employee_ID  Attrition_rate
# 0       TID_1          0.1588
# 1       TID_2          0.1424
# 2       TID_3          0.4758
# 3       TID_4          0.0846
# 4       TID_5          0.2388

# %%
train_df.describe()
# Out:
#                Age  Education_Level  Time_of_service  Time_since_promotion  \
# count  6588.000000      7000.000000      6856.000000           7000.000000
# mean     39.622799         3.187857        13.385064              2.367143
# std      13.606920         1.065102        10.364188              1.149395
# min      19.000000         1.000000         0.000000              0.000000
# 25%      27.000000         3.000000         5.000000              1.000000
# 50%      37.000000         3.000000        10.000000              2.000000
# 75%      52.000000         4.000000        21.000000              3.000000
# max      65.000000         5.000000        43.000000              4.000000
#
#        growth_rate  Travel_Rate   Post_Level    Pay_Scale  Work_Life_balance  \
# count  7000.000000  7000.000000  7000.000000  6991.000000        6989.000000
# mean     47.064286     0.817857     2.798000     6.006294           2.387895
# ...

# %% [markdown]
# ## Categorical Data types

# %% [markdown]
# * I dont think Employee Id playes any role in here. So, let's drop them.

# %%
train_df = train_df.drop(columns=['Employee_ID'], axis=1)
train_df.head()
# Out:
#   Gender   Age  Education_Level Relationship_Status     Hometown  \
# 0      F  42.0                4             Married     Franklin
# 1      M  24.0                3              Single  Springfield
# 2      F  58.0                3             Married      Clinton
# 3      F  26.0                3              Single      Lebanon
# 4      F  31.0                1             Married  Springfield
#
#                         Unit Decision_skill_possess  Time_of_service  \
# 0                         IT             Conceptual              4.0
# 1                  Logistics             Analytical              5.0
# 2                    Quality             Conceptual             27.0
# 3  Human Resource Management             Behavioral              4.0
# 4                  Logistics             Conceptual              5.0
#
#    Time_since_promotion  growth_rate  ...  Compensation_and_Benefits  \
# 0                     4           33  ...                      type2
# ...

# %%
# inspect the Gender column
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

plt.figure()
train_df.Attrition_rate.hist()
plt.show()

# %%
sns.violinplot(x='Attrition_rate', y='Gender', data=train_df)
plt.show()

# %% [markdown]
# Above violin plot shows that it doesn't matter much whether male or female, both have kind of same distribution in numbers below 0.4 attrition rate.

# %%
# let's move on and care less about the following feature Gender
# replace M with 1 and F with 0
train_df['Gender'] = train_df['Gender'].replace({'F':0, 'M':1})
train_df.head()
# Out:
#    Gender   Age  Education_Level Relationship_Status     Hometown  \
# 0       0  42.0                4             Married     Franklin
# 1       1  24.0                3              Single  Springfield
# 2       0  58.0                3             Married      Clinton
# 3       0  26.0                3              Single      Lebanon
# 4       0  31.0                1             Married  Springfield
#
#                         Unit Decision_skill_possess  Time_of_service  \
# 0                         IT             Conceptual              4.0
# 1                  Logistics             Analytical              5.0
# 2                    Quality             Conceptual             27.0
# 3  Human Resource Management             Behavioral              4.0
# 4                  Logistics             Conceptual              5.0
#
#    Time_since_promotion  growth_rate  ...  Compensation_and_Benefits  \
# 0                     4           33  ...                      type2
# ...

# %% [markdown]
# ### Relationship Status

# %%
counts, bins, patches = plt.hist(train_df.Relationship_Status.values)
for n, b in zip(counts, bins):
    if n!=0:
        plt.gca().text(b, n, str(n))
plt.show()

# %%
sns.violinplot(x='Attrition_rate', y='Relationship_Status', data=train_df)
plt.show()

# %%
# seems no interesting 
# replace with numeric vlaues and move on
train_df['Relationship_Status'] = train_df['Relationship_Status'].replace({'Single':0, 'Married':1})
train_df.head()
# Out:
#    Gender   Age  Education_Level  Relationship_Status     Hometown  \
# 0       0  42.0                4                    1     Franklin
# 1       1  24.0                3                    0  Springfield
# 2       0  58.0                3                    1      Clinton
# 3       0  26.0                3                    0      Lebanon
# 4       0  31.0                1                    1  Springfield
#
#                         Unit Decision_skill_possess  Time_of_service  \
# 0                         IT             Conceptual              4.0
# 1                  Logistics             Analytical              5.0
# 2                    Quality             Conceptual             27.0
# 3  Human Resource Management             Behavioral              4.0
# 4                  Logistics             Conceptual              5.0
#
#    Time_since_promotion  growth_rate  ...  Compensation_and_Benefits  \
# 0                     4           33  ...                      type2
# ...

# %% [markdown]
# ### Hometown

# %%
train_df.Hometown.value_counts()
# Out:
# Lebanon        2070
# Springfield    1736
# Franklin       1523
# Washington     1106
# Clinton         565
# Name: Hometown, dtype: int64

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(x='Hometown', y='Attrition_rate', data=train_df)
plt.show()

# %%
plt.hist(train_df['Hometown'])
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

train_df['Hometown'] = LabelEncoder().fit_transform(train_df['Hometown'])

# %%
train_df.head()
# Out:
#    Gender   Age  Education_Level  Relationship_Status  Hometown  \
# 0       0  42.0                4                    1         1
# 1       1  24.0                3                    0         3
# 2       0  58.0                3                    1         0
# 3       0  26.0                3                    0         2
# 4       0  31.0                1                    1         3
#
#                         Unit Decision_skill_possess  Time_of_service  \
# 0                         IT             Conceptual              4.0
# 1                  Logistics             Analytical              5.0
# 2                    Quality             Conceptual             27.0
# 3  Human Resource Management             Behavioral              4.0
# 4                  Logistics             Conceptual              5.0
#
#    Time_since_promotion  growth_rate  ...  Compensation_and_Benefits  \
# 0                     4           33  ...                      type2
# ...

# %% [markdown]
# ### Unit

# %%
train_df.Unit.value_counts()
# Out:
# IT                           1394
# Logistics                    1173
# Sales                         943
# Operarions                    706
# R&D                           680
# Purchasing                    504
# Accounting and Finance        496
# Human Resource Management     344
# Marketing                     212
# Production                    211
# Quality                       193
# Security                      144
# Name: Unit, dtype: int64

# %%
plt.figure(figsize=(24, 6))
sns.violinplot(x='Unit', y='Attrition_rate', data=train_df)
plt.show()

# %%
# Hell boring.
train_df['Unit'] = LabelEncoder().fit_transform(train_df['Unit'])
train_df.head()
# Out:
#    Gender   Age  Education_Level  Relationship_Status  Hometown  Unit  \
# 0       0  42.0                4                    1         1     2
# 1       1  24.0                3                    0         3     3
# 2       0  58.0                3                    1         0     8
# 3       0  26.0                3                    0         2     1
# 4       0  31.0                1                    1         3     3
#
#   Decision_skill_possess  Time_of_service  Time_since_promotion  growth_rate  \
# 0             Conceptual              4.0                     4           33
# 1             Analytical              5.0                     4           36
# 2             Conceptual             27.0                     3           51
# 3             Behavioral              4.0                     3           56
# 4             Conceptual              5.0                     4           62
#
#    ...  Compensation_and_Benefits  Work_Life_balance  VAR1    VAR2    VAR3  \
# ...

# %% [markdown]
# ### Decision skills

# %%
train_df.Decision_skill_possess.describe()
# Out:
# count           7000
# unique             4
# top       Conceptual
# freq            1756
# Name: Decision_skill_possess, dtype: object

# %%
train_df.Decision_skill_possess.value_counts()
# Out:
# Conceptual    1756
# Analytical    1755
# Directive     1753
# Behavioral    1736
# Name: Decision_skill_possess, dtype: int64

# %%
plt.figure()
sns.violinplot(x='Decision_skill_possess', y='Attrition_rate', data=train_df)
plt.show()

# %%
# Damn, gimme something interesting
train_df['Decision_skill_possess'] = LabelEncoder().fit_transform(train_df['Decision_skill_possess'])
train_df
# Out:
#       Gender   Age  Education_Level  Relationship_Status  Hometown  Unit  \
# 0          0  42.0                4                    1         1     2
# 1          1  24.0                3                    0         3     3
# 2          0  58.0                3                    1         0     8
# 3          0  26.0                3                    0         2     1
# 4          0  31.0                1                    1         3     3
# ...      ...   ...              ...                  ...       ...   ...
# 6995       0  23.0                5                    1         1     5
# 6996       0  44.0                1                    1         2     9
# 6997       0  49.0                3                    0         3     2
# 6998       0  47.0                3                    1         4    10
# 6999       0  58.0                3                    1         1     2
#
#       Decision_skill_possess  Time_of_service  Time_since_promotion  \
# ...

# %% [markdown]
# ### Compensation and Benefits

# %%
train_df.Compensation_and_Benefits.value_counts()
# Out:
# type2    3945
# type3    2382
# type4     353
# type0     187
# type1     133
# Name: Compensation_and_Benefits, dtype: int64

# %%
sns.violinplot(x='Compensation_and_Benefits', y='Attrition_rate', data=train_df)
plt.show()

# %%
train_df.Compensation_and_Benefits
# Out:
# 0       type2
# 1       type2
# 2       type2
# 3       type2
# 4       type3
#         ...
# 6995    type3
# 6996    type3
# 6997    type2
# 6998    type0
# 6999    type2
# Name: Compensation_and_Benefits, Length: 7000, dtype: object

# %%
train_df['Compensation_and_Benefits'] = LabelEncoder().fit_transform(train_df['Compensation_and_Benefits'])
train_df.head()
# Out:
#    Gender   Age  Education_Level  Relationship_Status  Hometown  Unit  \
# 0       0  42.0                4                    1         1     2
# 1       1  24.0                3                    0         3     3
# 2       0  58.0                3                    1         0     8
# 3       0  26.0                3                    0         2     1
# 4       0  31.0                1                    1         3     3
#
#    Decision_skill_possess  Time_of_service  Time_since_promotion  growth_rate  \
# 0                       2              4.0                     4           33
# 1                       0              5.0                     4           36
# 2                       2             27.0                     3           51
# 3                       1              4.0                     3           56
# 4                       2              5.0                     4           62
#
# ...

# %%
train_df = train_df.fillna(0)

# %%
# lets dig abouts correlations
plt.figure(figsize=(25, 25))
sns.heatmap(train_df.corr(), annot=True)
plt.show()

# %%
abs(train_df.corr()['Attrition_rate']).sort_values(ascending=False)
# Out:
# Attrition_rate               1.000000
# Gender                       0.028544
# Compensation_and_Benefits    0.025175
# Unit                         0.024324
# VAR2                         0.022906
# Work_Life_balance            0.021115
# Time_of_service              0.019863
# Decision_skill_possess       0.018104
# Post_Level                   0.016402
# Pay_Scale                    0.015643
# VAR7                         0.015299
# growth_rate                  0.014247
# Time_since_promotion         0.013880
# Travel_Rate                  0.012608
# Relationship_Status          0.009107
# Age                          0.008505
# Education_Level              0.008143
# VAR1                         0.008073
# Hometown                     0.006784
# VAR5                         0.004770
# VAR6                         0.003130
# VAR3                         0.001245
# VAR4                         0.001051
# Name: Attrition_rate, dtype: float64

# %%
from sklearn.model_selection import train_test_split
import xgboost as xgb
from sklearn.metrics import mean_squared_error

# %%
# construct the Data Matrix for XgBdoost
dm = xgb.DMatrix(data=train_df.drop(['Attrition_rate'], axis=1), label=train_df['Attrition_rate'])

# %%
from sklearn.model_selection import GridSearchCV
import numpy as np

# %%
xgbreg = xgb.sklearn.XGBRegressor()
parameters = {'nthread':[4], #when use hyperthread, xgboost may become slower
              'objective':['reg:linear'],
              'learning_rate': [.03, 0.05, .07], #so called `eta` value
              'max_depth': [5, 6, 7],
              'min_child_weight': [4],
              'silent': [1],
              'subsample': [0.7],
              'colsample_bytree': [0.7],
              'n_estimators': [500]}

xgb_grid = GridSearchCV(xgbreg,
                        parameters,
                        cv = 2,
                        n_jobs = 5,
                        verbose=True)

xgb_grid.fit(train_df.drop(['Attrition_rate'], axis=1), train_df['Attrition_rate'])
# Out:
# Fitting 2 folds for each of 9 candidates, totalling 18 fits
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  18 out of  18 | elapsed:   22.2s finished
# [01:05:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.1.0/src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [01:05:16] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [01:05:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.1.0/src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# ...

# %%
xgb_grid.best_score_
# Out:
# -0.057827918637438414

# %%
xgb_grid.best_estimator_
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.7, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.03, max_delta_step=0, max_depth=5,
#              min_child_weight=4, missing=nan, monotone_constraints='()',
#              n_estimators=500, n_jobs=4, nthread=4, num_parallel_tree=1,
#              objective='reg:linear', random_state=0, reg_alpha=0, reg_lambda=1,
#              scale_pos_weight=1, silent=1, subsample=0.7, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
xgb_grid.best_params_
# Out:
# {'colsample_bytree': 0.7,
#  'learning_rate': 0.03,
#  'max_depth': 5,
#  'min_child_weight': 4,
#  'n_estimators': 500,
#  'nthread': 4,
#  'objective': 'reg:linear',
#  'silent': 1,
#  'subsample': 0.7}

# %%
params_updated = xgb_grid.best_params_
cv_results = xgb.cv(dtrain=dm, params=params_updated, nfold=3,
                    num_boost_round=50,early_stopping_rounds=10,metrics="rmse", as_pandas=True, seed=123)
# Out:
# [01:05:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.1.0/src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [01:05:18] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { n_estimators, silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [01:05:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.1.0/src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [01:05:18] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { n_estimators, silent } might not be used.
#
# ...

# %%
cv_results.head()
# Out:
#    train-rmse-mean  train-rmse-std  test-rmse-mean  test-rmse-std
# 0         0.353881        0.000886        0.353969       0.001815
# 1         0.346100        0.000877        0.346304       0.001826
# 2         0.338654        0.000891        0.338991       0.001824
# 3         0.331504        0.000839        0.331950       0.001874
# 4         0.324602        0.000843        0.325150       0.001896

# %%
pred = xgb_grid.predict(X=train_df.drop(['Attrition_rate'], axis=1))

# %%
pred
# Out:
# array([0.17124096, 0.15947041, 0.17428261, ..., 0.3078934 , 0.27022964,
#        0.1491302 ], dtype=float32)

# %%
train_df['Attrition_rate'].values
# Out:
# array([0.1841, 0.067 , 0.0851, ..., 0.7847, 0.4162, 0.091 ])

# %%
np.sqrt(mean_squared_error(y_pred=pred, y_true=train_df['Attrition_rate'].values))
# Out:
# 0.14676680070293824

# %%
test_df
# Out:
#      Employee_ID Gender   Age  Education_Level Relationship_Status  \
# 0      EID_22713      F  32.0                5              Single
# 1       EID_9658      M  65.0                2              Single
# 2      EID_22203      M  52.0                3             Married
# 3       EID_7652      M  50.0                5              Single
# 4       EID_6516      F  44.0                3             Married
# ...          ...    ...   ...              ...                 ...
# 2995   EID_22547      F  32.0                3              Single
# 2996   EID_10066      F   NaN                2              Single
# 2997    EID_7126      F  60.0                4              Single
# 2998    EID_4929      F  51.0                1             Married
# 2999   EID_24750      F  45.0                1              Single
#
#          Hometown       Unit Decision_skill_possess  Time_of_service  \
# 0     Springfield        R&D             Conceptual              7.0
# ...

# %%
(test_df[test_df.columns].isna()).sum()
# Out:
# Employee_ID                    0
# Gender                         0
# Age                          161
# Education_Level                0
# Relationship_Status            0
# Hometown                       0
# Unit                           0
# Decision_skill_possess         0
# Time_of_service               52
# Time_since_promotion           0
# growth_rate                    0
# Travel_Rate                    0
# Post_Level                     0
# Pay_Scale                      3
# Compensation_and_Benefits      0
# Work_Life_balance              5
# VAR1                           0
# VAR2                         217
# VAR3                           0
# VAR4                         298
# VAR5                           0
# VAR6                           0
# VAR7                           0
# dtype: int64

# %%
test_df[['Age', 'Time_of_service', 'Pay_Scale', 'Work_Life_balance', 'VAR2', 'VAR4']] = test_df[['Age', 'Time_of_service', 'Pay_Scale', 'Work_Life_balance', 'VAR2', 'VAR4']].fillna(0)

# %%
test_df[test_df.columns].isna().sum()
# Out:
# Employee_ID                  0
# Gender                       0
# Age                          0
# Education_Level              0
# Relationship_Status          0
# Hometown                     0
# Unit                         0
# Decision_skill_possess       0
# Time_of_service              0
# Time_since_promotion         0
# growth_rate                  0
# Travel_Rate                  0
# Post_Level                   0
# Pay_Scale                    0
# Compensation_and_Benefits    0
# Work_Life_balance            0
# VAR1                         0
# VAR2                         0
# VAR3                         0
# VAR4                         0
# VAR5                         0
# VAR6                         0
# VAR7                         0
# dtype: int64

# %%
(test_df[test_df.columns]==0).sum()
# Out:
# Employee_ID                    0
# Gender                         0
# Age                          161
# Education_Level                0
# Relationship_Status            0
# Hometown                       0
# Unit                           0
# Decision_skill_possess         0
# Time_of_service              112
# Time_since_promotion          62
# growth_rate                    0
# Travel_Rate                  923
# Post_Level                     0
# Pay_Scale                      3
# Compensation_and_Benefits      0
# Work_Life_balance              5
# VAR1                           0
# VAR2                         217
# VAR3                           0
# VAR4                         298
# VAR5                           0
# VAR6                           0
# VAR7                           0
# dtype: int64

# %%
test_df['Age'] = test_df['Age'].replace(0, test_df.Age.median())
test_df['Time_of_service'] = test_df['Time_of_service'].replace(0, test_df.Time_of_service.median())
test_df['Time_since_promotion'] = test_df['Time_since_promotion'].replace(0, test_df.Time_since_promotion.median())
test_df['Travel_Rate'] = test_df['Travel_Rate'].replace(0, test_df.Travel_Rate.median())
test_df['VAR2'] = test_df['VAR2'].replace(0, test_df.VAR2.median())
test_df['VAR4'] = test_df['VAR4'].replace(0, test_df.VAR4.median())
test_df['Pay_Scale'] = test_df['Pay_Scale'].replace(0, test_df.Pay_Scale.median())
test_df['Work_Life_balance'] = test_df['Work_Life_balance'].replace(0, test_df.Work_Life_balance.median())
(test_df[test_df.columns]==0).sum()
# Out:
# Employee_ID                    0
# Gender                         0
# Age                            0
# Education_Level                0
# Relationship_Status            0
# Hometown                       0
# Unit                           0
# Decision_skill_possess         0
# Time_of_service                0
# Time_since_promotion           0
# growth_rate                    0
# Travel_Rate                    0
# Post_Level                     0
# Pay_Scale                      0
# Compensation_and_Benefits      0
# Work_Life_balance              0
# VAR1                           0
# VAR2                         217
# VAR3                           0
# VAR4                           0
# VAR5                           0
# VAR6                           0
# VAR7                           0
# dtype: int64

# %%
# now test_df is our test_df Mean
# Lets proceed to do just preprocessing in testdf as well
for i in test_df.columns[test_df.dtypes=='object'][1:]:
    test_df[i] = LabelEncoder().fit_transform(test_df[i])
    #test_df[i] = test_df[i].apply(lambda x : LabelEncoder().fit_transform(x))
test_df.head()
# Out:
#   Employee_ID  Gender   Age  Education_Level  Relationship_Status  Hometown  \
# 0   EID_22713       0  32.0                5                    1         3
# 1    EID_9658       1  65.0                2                    1         2
# 2   EID_22203       1  52.0                3                    0         3
# 3    EID_7652       1  50.0                5                    1         4
# 4    EID_6516       0  44.0                3                    0         1
#
#    Unit  Decision_skill_possess  Time_of_service  Time_since_promotion  ...  \
# 0     9                       2              7.0                     4  ...
# 1     2                       3             41.0                     2  ...
# 2    10                       3             21.0                     3  ...
# 3     4                       0             11.0                     4  ...
# 4     9                       2             12.0                     4  ...
#
# ...

# %%
test_df['score'] = xgb_grid.predict(test_df.drop(['Employee_ID'], axis=1))

# %%
test_df
# Out:
#      Employee_ID  Gender   Age  Education_Level  Relationship_Status  \
# 0      EID_22713       0  32.0                5                    1
# 1       EID_9658       1  65.0                2                    1
# 2      EID_22203       1  52.0                3                    0
# 3       EID_7652       1  50.0                5                    1
# 4       EID_6516       0  44.0                3                    0
# ...          ...     ...   ...              ...                  ...
# 2995   EID_22547       0  32.0                3                    1
# 2996   EID_10066       0  37.0                2                    1
# 2997    EID_7126       0  60.0                4                    1
# 2998    EID_4929       0  51.0                1                    0
# 2999   EID_24750       0  45.0                1                    1
#
#       Hometown  Unit  Decision_skill_possess  Time_of_service  \
# 0            3     9                       2              7.0
# ...

# %%
submissiondf = pd.DataFrame()
submissiondf['Employee_ID'] = test_df['Employee_ID']
submissiondf['Attrition_rate'] = xgMain.predict(test_df.drop(['Employee_ID', 'score'], axis=1))
len(submissiondf)
# Out:
# 3000

# %%
submissiondf
# Out:
#      Employee_ID  Attrition_rate
# 0      EID_22713        0.205291
# 1       EID_9658        0.397985
# 2      EID_22203        0.232633
# 3       EID_7652        0.210383
# 4       EID_6516        0.229814
# ...          ...             ...
# 2995   EID_22547        0.210373
# 2996   EID_10066        0.149577
# 2997    EID_7126        0.053778
# 2998    EID_4929        0.427956
# 2999   EID_24750        0.016901
#
# [3000 rows x 2 columns]

# %%
submissiondf.mean()
# Out:
# Attrition_rate    0.194708
# dtype: float32

# %%
submissiondf.to_csv('Submission_NI.csv', index=False)

# %%
from sklearn.base import TransformerMixin
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.linear_model import LinearRegression, Ridge

# %%
class RidgeTransformer(Ridge, TransformerMixin):

    def transform(self, X, *_):
        return self.predict(X).reshape(len(X), -1)


class RandomForestTransformer(RandomForestRegressor, TransformerMixin):

    def transform(self, X, *_):
        return self.predict(X).reshape(len(X), -1)


class KNeighborsTransformer(KNeighborsRegressor, TransformerMixin):

    def transform(self, X, *_):
        return self.predict(X).reshape(len(X), -1)


def build_model():
    ridge_transformer = Pipeline(steps=[
        ('scaler', StandardScaler()),
        ('poly_feats', PolynomialFeatures()),
        ('ridge', RidgeTransformer())
    ])

    pred_union = FeatureUnion(
        transformer_list=[
            ('ridge', ridge_transformer),
            ('rand_forest', RandomForestTransformer()),
            ('knn', KNeighborsTransformer())
        ],
        n_jobs=2
    )

    model = Pipeline(steps=[
        ('pred_union', pred_union),
        ('lin_regr', LinearRegression())
    ])

    return model


print('Build and fit a model...')

model = build_model()
# Out:
# Build and fit a model...

# %%
model.fit(train_df.drop(['Attrition_rate'], axis=1), train_df['Attrition_rate'])
# Out:
# Pipeline(memory=None,
#          steps=[('pred_union',
#                  FeatureUnion(n_jobs=2,
#                               transformer_list=[('ridge',
#                                                  Pipeline(memory=None,
#                                                           steps=[('scaler',
#                                                                   StandardScaler(copy=True,
#                                                                                  with_mean=True,
#                                                                                  with_std=True)),
#                                                                  ('poly_feats',
#                                                                   PolynomialFeatures(degree=2,
#                                                                                      include_bias=True,
#                                                                                      interaction_only=False,
# ...

# %%
pred_train = model.predict(train_df.drop(['Attrition_rate'], axis=1))
print(1 - np.sqrt(mean_squared_error(train_df['Attrition_rate'], pred_train)))
# Out:
# 0.9277471158641031

# %%
def replace_categorical(df):
    """ Apply label encoding instead."""
    for col in df.columns:
        if df[col].dtype == 'object':
            df[col] = LabelEncoder().fit_transform(df[col])

    return df

# %%
test_df = replace_categorical(test_df)
test_df
# Out:
#       Employee_ID  Gender   Age  Education_Level  Relationship_Status  \
# 0            1702       0  32.0                5                    1
# 1            2958       1  65.0                2                    1
# 2            1628       1  52.0                3                    0
# 3            2709       1  50.0                5                    1
# 4            2580       0  44.0                3                    0
# ...           ...     ...   ...              ...                  ...
# 2995         1677       0  32.0                3                    1
# 2996           12       0   0.0                2                    1
# 2997         2656       0  60.0                4                    1
# 2998         2405       0  51.0                1                    0
# 2999         1990       0  45.0                1                    1
#
#       Hometown  Unit  Decision_skill_possess  Time_of_service  \
# 0            3     9                       2              7.0
# ...

# %%
predictions = model.predict(test_df.drop(['Employee_ID'], axis=1))
predictions
# Out:
# array([0.19145981, 0.3198395 , 0.31339009, ..., 0.07082009, 0.13765846,
#        0.11758654])

# %%
ans = pd.DataFrame()
ans['Employee_ID'] = test_df['Employee_ID'].iloc[:]
ans['Attrition_rate'] = predictions
ans.to_csv('Answer.csv', index=False)
ans
# Out:
#      Employee_ID  Attrition_rate
# 0      EID_22713        0.191460
# 1       EID_9658        0.319839
# 2      EID_22203        0.313390
# 3       EID_7652        0.245234
# 4       EID_6516        0.216354
# ...          ...             ...
# 2995   EID_22547        0.080333
# 2996   EID_10066        0.303220
# 2997    EID_7126        0.070820
# 2998    EID_4929        0.137658
# 2999   EID_24750        0.117587
#
# [3000 rows x 2 columns]

# %%
train_df.Attrition_rate.mean()
# Out:
# 0.1893761285714282

# %%
ans.Attrition_rate.mean()
# Out:
# 0.19996505374116044

# %%
params = xgb_grid.best_params_
params
# Out:
# {'colsample_bytree': 0.7,
#  'learning_rate': 0.03,
#  'max_depth': 5,
#  'min_child_weight': 4,
#  'n_estimators': 500,
#  'nthread': 4,
#  'objective': 'reg:linear',
#  'silent': 1,
#  'subsample': 0.7}

# %%
xgMain = xgb.XGBRegressor()

# %%
X_train, X_test, y_train, y_test = train_test_split(train_df.drop(['Attrition_rate'], axis=1), train_df['Attrition_rate'], test_size=0.15, random_state=42)
print(len(X_train), len(y_train), len(X_test), len(y_test))
# Out:
# 5950 5950 1050 1050

# %%
xgMain.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=0, num_parallel_tree=1,
#              objective='reg:squarederror', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
np.sqrt(mean_squared_error(y_test, xgMain.predict(X_test)))
# Out:
# 0.20839172894309535

# %%
np.sqrt(mean_squared_error(test_df['score'], xgMain.predict(test_df.drop(['Employee_ID', 'score'], axis=1))))
# Out:
# 0.0700401
